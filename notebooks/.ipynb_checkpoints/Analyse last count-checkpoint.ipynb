# %%
import pandas as pd

# %%
train_mini = pd.read_csv('../data/train_mini.csv')

# %%
train_mini.head()
# Out:
#    row_id  timestamp  user_id  content_id  content_type_id  task_container_id  \
# 0  365541          0  7136928        7900                0                  0
# 1  365542      23989  7136928        7876                0                  1
# 2  365543      48079  7136928         175                0                  2
# 3  365544      74835  7136928        1278                0                  3
# 4  365545     192811  7136928        2063                0                  4
#
#    user_answer  answered_correctly  prior_question_elapsed_time  \
# 0            2                   0                          NaN
# 1            0                   0                      21000.0
# 2            3                   0                      20000.0
# 3            1                   0                      21000.0
# 4            3                   0                      20000.0
#
#   prior_question_had_explanation
# 0                            NaN
# 1                          False
# ...

# %%
len(train_mini.user_id.unique())
# Out:
# 100

# %%
grouped = train_mini.groupby(['user_id']).agg(['count'])
grouped.head()
# Out:
#          row_id timestamp content_id content_type_id task_container_id  \
#           count     count      count           count             count
# user_id
# 7136928      30        30         30              30                30
# 22318239     20        20         20              20                20
# 51771056    733       733        733             733               733
# 53424674     43        43         43              43                43
# 64764301     13        13         13              13                13
#
#          user_answer answered_correctly prior_question_elapsed_time  \
#                count              count                       count
# user_id
# 7136928           30                 30                          29
# 22318239          20                 20                          19
# 51771056         733                733                         715
# 53424674          43                 43                          42
# ...

# %%
train_mini[train_mini.user_id == 64764301]
# Out:
#       row_id  timestamp   user_id  content_id  content_type_id  \
# 826  2976971          0  64764301        4204                0
# 827  2976972      24418  64764301        4075                0
# 828  2976973      55743  64764301        5190                0
# 829  2976974     109667  64764301        4729                0
# 830  2976975     130685  64764301         378                0
# 831  2976976     178403  64764301        5178                0
# 832  2976977     232293  64764301        5987                0
# 833  2976978  610249642  64764301         349                0
# 834  2976979  610280481  64764301         747                0
# 835  2976980  610305650  64764301         493                0
# 836  2976981  610327302  64764301         294                0
# 837  2976982  610347384  64764301         573                0
# 838  2976983  610367939  64764301        1325                0
#
#      task_container_id  user_answer  answered_correctly  \
# ...

# %%
grouped.columns
# Out:
# MultiIndex([(                        'row_id', 'count'),
#             (                     'timestamp', 'count'),
#             (                    'content_id', 'count'),
#             (               'content_type_id', 'count'),
#             (             'task_container_id', 'count'),
#             (                   'user_answer', 'count'),
#             (            'answered_correctly', 'count'),
#             (   'prior_question_elapsed_time', 'count'),
#             ('prior_question_had_explanation', 'count')],
#            )

# %%
grouped.describe()
# Out:
#             row_id    timestamp   content_id content_type_id  \
#              count        count        count           count
# count    100.00000    100.00000    100.00000       100.00000
# mean     268.92000    268.92000    268.92000       268.92000
# std     1224.74552   1224.74552   1224.74552      1224.74552
# min        7.00000      7.00000      7.00000         7.00000
# 25%       26.00000     26.00000     26.00000        26.00000
# 50%       40.00000     40.00000     40.00000        40.00000
# 75%      134.00000    134.00000    134.00000       134.00000
# max    11974.00000  11974.00000  11974.00000     11974.00000
#
#       task_container_id  user_answer answered_correctly  \
#                   count        count              count
# count         100.00000    100.00000          100.00000
# mean          268.92000    268.92000          268.92000
# std          1224.74552   1224.74552         1224.74552
# min             7.00000      7.00000            7.00000
# ...
