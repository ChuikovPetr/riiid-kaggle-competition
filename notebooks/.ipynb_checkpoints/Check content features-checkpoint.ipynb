# %%
import numpy as np
import pandas as pd
pd.set_option('display.float_format', '{:.4f}'.format)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)

# %%
# %%time
for_train = pd.read_csv('../data/experiment_1/for_train.csv')
for_train.shape
# Out:
# CPU times: user 5.38 ms, sys: 2.46 ms, total: 7.85 ms
# Wall time: 7.14 ms
# (2156, 3)

# %%
# %%time
vitrine = pd.read_csv('../data/experiment_1/vitrine.csv')
vitrine.shape
# Out:
# CPU times: user 31.7 ms, sys: 11 ms, total: 42.6 ms
# Wall time: 43.5 ms
# (26892, 14)

# %%
# %%time
limit_vitrine = pd.read_csv('../data/experiment_1/limit_vitrine.csv')
limit_vitrine.shape
# Out:
# CPU times: user 30.7 ms, sys: 7.14 ms, total: 37.8 ms
# Wall time: 38.3 ms
# (26093, 14)

# %%
vitrine.user_id.unique()
# Out:
# array([   7136928,   22318239,   51771056,   53424674,   64764301,
#          82977466,   94999086,  106324700,  108822628,  137817081,
#         141264833,  217412465,  235233876,  235832844,  237524996,
#         252941168,  269060757,  337576619,  348461215,  367840615,
#         373598450,  406901956,  409019335,  468048049,  515668244,
#         519744118,  550366047,  562186265,  584872865,  616161602,
#         616580486,  624222398,  634891095,  658520354,  736371818,
#         751871997,  761021960,  761800801,  789631718,  845636456,
#         854863946,  878817883,  891642780,  900124353,  946026077,
#         951606580,  957818828, 1014937471, 1054103172, 1058520883,
#        1071312962, 1102511752, 1138522179, 1143715769, 1154226251,
#        1165196379, 1191572932, 1223491298, 1247503470, 1258176764,
#        1269589690, 1300608200, 1314342162, 1319452599, 1327647142,
#        1420344126, 1443598919, 1462950044, 1485450502, 1490239788,
# ...

# %%
vitrine[vitrine.user_id == 761800801]
# Out:
#             id   timestamp    user_id  content_id  content_type_id  \
# 7478  35676780           0  761800801        4105                0
# 7479  35676781       29298  761800801          84                0
# 7480  35676782       42368  761800801        6417                0
# 7481  35676783       74304  761800801        4726                0
# 7482  35676784       96233  761800801        5148                0
# 7483  35676785      130113  761800801        6245                0
# 7484  35676786      148392  761800801        8225                0
# 7485  35676787      180625  761800801        3614                0
# 7486  35676788      215633  761800801        6375                0
# 7487  35676789      239671  761800801        5269                0
# 7488  35676790      416000  761800801        4414                0
# 7489  35676791      685848  761800801        6318                0
# 7490  35676792      854108  761800801       13379                1
# ...

# %%
limit_vitrine[limit_vitrine.user_id == 761800801]
# Out:
#             id  timestamp    user_id  content_id  content_type_id  \
# 7182  35676780          0  761800801        4105                0
# 7183  35676781      29298  761800801          84                0
# 7184  35676782      42368  761800801        6417                0
# 7185  35676783      74304  761800801        4726                0
# 7186  35676784      96233  761800801        5148                0
# 7187  35676785     130113  761800801        6245                0
# 7188  35676786     148392  761800801        8225                0
# 7189  35676787     180625  761800801        3614                0
# 7190  35676788     215633  761800801        6375                0
# 7191  35676789     239671  761800801        5269                0
# 7192  35676790     416000  761800801        4414                0
# 7193  35676791     685848  761800801        6318                0
# 7194  35676792     854108  761800801       13379                1
# ...

# %%
content_vitrine = pd.read_csv('../data/experiment_1/content_vitrine.csv')
content_vitrine.shape
# Out:
# (2156, 34)

# %%
content_vitrine.isna().sum(axis = 0).sum()
# Out:
# 0

# %%
content_vitrine.head()
# Out:
#            id  content_id   timestamp  prior_question_had_explanation   part  \
# 0 365548.0000   3364.0000 290933.0000                          0.0000 4.0000
# 1 365549.0000   3365.0000 290933.0000                          0.0000 4.0000
# 2 365550.0000   3363.0000 290933.0000                          0.0000 4.0000
# 3 365551.0000   2947.0000 370847.0000                          0.0000 4.0000
# 4 365552.0000   2948.0000 370847.0000                          0.0000 4.0000
#
#    kmean_cluster  content_mean_answered_correctly  \
# 0         6.0000                           0.6000
# 1         6.0000                           0.3778
# 2         6.0000                           0.2609
# 3         6.0000                           0.1429
# 4         6.0000                           0.3095
#
#    content_sum_answered_correctly  content_count_answered_correctly  \
# 0                         27.0000                           45.0000
# ...

# %%
features = pd.read_csv('../data/experiment_1/features.csv')
features.shape
# Out:
# (2156, 88)

# %%
features.columns
# Out:
# Index(['id', 'timestamp', 'prior_question_elapsed_time',
#        'prior_question_had_explanation', 'part', 'kmean_cluster',
#        'lect_user_part', 'lect_user_kmean_cluster', 'lect_user',
#        'lect_user_part_concept', 'lect_user_kmean_cluster_concept',
#        'lect_user_concept', 'lect_user_part_intention',
#        'lect_user_kmean_cluster_intention', 'lect_user_intention',
#        'lect_user_part_solving_question',
#        'lect_user_kmean_cluster_solving_question',
#        'lect_user_solving_question', 'lect_user_part_starter',
#        'lect_user_kmean_cluster_starter', 'lect_user_starter',
#        'user_sum_answered_correctly', 'user_count_answered_correctly',
#        'user_mean_answered_correctly', 'user_ema_answered_correctly',
#        'user_he_sum_answered_correctly', 'user_he_count_answered_correctly',
#        'user_he_mean_answered_correctly', 'user_he_ema_answered_correctly',
#        'user_sum_prior_question_elapsed_time',
# ...

# %%
features.isna().sum(axis = 0).sum()
# Out:
# 0

# %%
features.head()
# Out:
#            id   timestamp  prior_question_elapsed_time  \
# 0 365548.0000 290933.0000                   38000.0000
# 1 365549.0000 290933.0000                   38000.0000
# 2 365550.0000 290933.0000                   38000.0000
# 3 365551.0000 370847.0000                   31333.0000
# 4 365552.0000 370847.0000                   31333.0000
#
#    prior_question_had_explanation   part  kmean_cluster  lect_user_part  \
# 0                               0 4.0000         6.0000          0.0000
# 1                               0 4.0000         6.0000          0.0000
# 2                               0 4.0000         6.0000          0.0000
# 3                               0 4.0000         6.0000          0.0000
# 4                               0 4.0000         6.0000          0.0000
#
#    lect_user_kmean_cluster  lect_user  lect_user_part_concept  \
# 0                   0.0000     0.0000                  0.0000
# 1                   0.0000     0.0000                  0.0000
# ...
