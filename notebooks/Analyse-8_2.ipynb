# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

import pickle
import sys

from ccf.SplitTimeSeries import naturalReindexDF
    
    
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 20000)

# %%
analyse = pd.read_csv('../analytics/block_vars_lgb_base_user_id_full_no_tail_8_2_15.csv')
analyse
# Out:
#     count  confidence_lower  confidence_upper       mean       std        min  \
# 0  1000.0         52.650396         53.787907  53.230609  0.292428  52.369378
#
#          25%        50%        75%        max  lower_boundary  upper_boundary  \
# 0  53.035234  53.236205  53.423453  54.204663       52.657451       53.803767
#
#         IQR  lower_whiskers  upper_whiskers  real_mean  real_std  lower_real  \
# 0  0.388219       52.452906        54.00578  53.230683  0.290999   52.660324
#
#    upper_real                macro  macro_mean  macro_std  macro_lower_bound  \
# 0   53.801042  [53.22503978203619]    53.22504        1.0           51.26504
#
#    macro_upper_bound                                      curr_features  \
# 0           55.18504  ['ema_chng_timestamp', 'content_mean_answered_...
#
#                      new_var  count_vars  best_in_iter
# 0  rel_user_content_ema_answ         107             1

# %%
analyse = pd.read_csv('../analytics/block_vars_lgb_user_id_full_no_tail_no_param.csv')
analyse
# Out:
#     count  confidence_lower  confidence_upper       mean       std       min  \
# 0  1000.0         51.059632         52.238083  51.642492  0.304131  50.66267
#
#          25%       50%        75%        max  lower_boundary  upper_boundary  \
# 0  51.424795  51.64808  51.847191  52.588148       51.046395       52.238589
#
#         IQR  lower_whiskers  upper_whiskers  real_mean  real_std  lower_real  \
# 0  0.422396       50.791201       52.480784  51.642589  0.302773   51.049154
#
#    upper_real                 macro  macro_mean  macro_std  macro_lower_bound  \
# 0   52.236025  [51.637417558828446]   51.637418        1.0          49.677418
#
#    macro_upper_bound                                      curr_features  \
# 0          53.597418  ['trend_user_he_mean_answ', 'lag_expl_and_part...
#
#                            new_var  count_vars  best_in_iter
# 0  content_mean_answered_correctly         107             1

# %%
analyse = pd.read_csv('../analytics/block_vars_lgb_user_id_full_no_tail.csv')
analyse
# Out:
#     count  confidence_lower  confidence_upper       mean       std        min  \
# 0  1000.0         50.884234         52.015142  51.435897  0.296644  50.535996
#
#        25%        50%        75%        max  lower_boundary  upper_boundary  \
# 0  51.2456  51.433931  51.631615  52.562695       50.854475       52.017319
#
#         IQR  lower_whiskers  upper_whiskers  real_mean  real_std  lower_real  \
# 0  0.386016       50.666576       52.210639  51.435276  0.293036   50.860926
#
#    upper_real                 macro  macro_mean  macro_std  macro_lower_bound  \
# 0   52.009627  [51.439979184222565]   51.439979        1.0          49.479979
#
#    macro_upper_bound                                      curr_features  \
# 0          53.399979  ['trend_user_he_mean_answ', 'lag_expl_and_part...
#
#                            new_var  count_vars  best_in_iter
# 0  content_mean_answered_correctly         107             1

# %%
analyse = pd.read_csv('../analytics/block_vars_lgb_user_id_4.csv')
analyse
# Out:
#     count  confidence_lower  confidence_upper      mean       std        min  \
# 0  1000.0         49.021449           50.0199  49.53167  0.256012  48.707966
#
#          25%       50%        75%        max  lower_boundary  upper_boundary  \
# 0  49.363293  49.53519  49.711547  50.245183       49.029887       50.033453
#
#         IQR  lower_whiskers  upper_whiskers  real_mean  real_std  lower_real  \
# 0  0.348254       48.840913       50.233927  49.531841  0.255454   49.031151
#
#    upper_real               macro  macro_mean  macro_std  macro_lower_bound  \
# 0   50.032531  [49.5246584842955]   49.524658        1.0          47.564658
#
#    macro_upper_bound                                      curr_features  \
# 0          51.484658  ['trend_user_he_mean_answ', 'lag_expl_and_part...
#
#                            new_var  count_vars  best_in_iter
# 0  content_mean_answered_correctly         107             1

# %%
analyse = pd.read_csv('../analytics/block_vars_lgb_user_id_23.csv')
analyse
# Out:
#     count  confidence_lower  confidence_upper       mean       std        min  \
# 0  1000.0         48.542319         49.551442  49.037643  0.255267  48.278803
#
#          25%        50%        75%        max  lower_boundary  upper_boundary  \
# 0  48.859213  49.030928  49.212545  49.818955       48.537319       49.537966
#
#         IQR  lower_whiskers  upper_whiskers  real_mean  real_std  lower_real  \
# 0  0.353332       48.329216       49.742542  49.037558   0.25468   48.538385
#
#    upper_real                macro  macro_mean  macro_std  macro_lower_bound  \
# 0   49.536732  [49.03170660916405]   49.031707        1.0          47.071707
#
#    macro_upper_bound                                      curr_features  \
# 0          50.991707  ['trend_user_he_mean_answ', 'lag_expl_and_part...
#
#                            new_var  count_vars  best_in_iter
# 0  content_mean_answered_correctly         107             1

# %%
analyse = pd.read_csv('../analytics/block_vars_lgb_user_id_full.csv')
analyse
# Out:
#     count  confidence_lower  confidence_upper       mean       std        min  \
# 0  1000.0         47.879719         48.857367  48.360859  0.246844  47.656974
#
#          25%        50%        75%       max  lower_boundary  upper_boundary  \
# 0  48.201809  48.369218  48.513118  49.19816       47.877045       48.844673
#
#         IQR  lower_whiskers  upper_whiskers  real_mean  real_std  lower_real  \
# 0  0.311309       47.734846       48.980082  48.360445  0.244871   47.880499
#
#    upper_real                macro  macro_mean  macro_std  macro_lower_bound  \
# 0   48.840392  [48.36066354186181]   48.360664        1.0          46.400664
#
#    macro_upper_bound                                      curr_features  \
# 0          50.320664  ['trend_user_he_mean_answ', 'lag_expl_and_part...
#
#                            new_var  count_vars  best_in_iter
# 0  content_mean_answered_correctly         107             1

# %%
analyse = pd.read_csv('../analytics/block_vars_lgb_user_id.csv')
analyse
# Out:
#     count  confidence_lower  confidence_upper       mean       std        min  \
# 0  1000.0         48.179652         49.336791  48.762913  0.294487  47.866225
#
#          25%        50%        75%        max  lower_boundary  upper_boundary  \
# 0  48.555477  48.765302  48.975587  49.583617       48.185718       49.340108
#
#        IQR  lower_whiskers  upper_whiskers  real_mean  real_std  lower_real  \
# 0  0.42011       47.925312       49.605752  48.762971  0.294316   48.186112
#
#    upper_real                 macro  macro_mean  macro_std  macro_lower_bound  \
# 0    49.33983  [48.755403520311866]   48.755404        1.0          46.795404
#
#    macro_upper_bound                                      curr_features  \
# 0          50.715404  ['trend_user_he_mean_answ', 'lag_expl_and_part...
#
#                            new_var  count_vars  best_in_iter
# 0  content_mean_answered_correctly         107             1

# %%
analyse = pd.read_csv('../analytics/block_vars_lgb_new_val_strat.csv')
analyse
# Out:
#     count  confidence_lower  confidence_upper       mean       std       min  \
# 0  1000.0           47.3712         48.505665  47.937773  0.290395  47.08964
#
#       25%        50%        75%        max  lower_boundary  upper_boundary  \
# 0  47.747  47.924733  48.128524  48.827748       47.368599       48.506947
#
#         IQR  lower_whiskers  upper_whiskers  real_mean  real_std  lower_real  \
# 0  0.381524       47.174713       48.700811  47.937448  0.289021   47.370967
#
#    upper_real                 macro  macro_mean  macro_std  macro_lower_bound  \
# 0   48.503928  [47.924204421073746]   47.924204        1.0          45.964204
#
#    macro_upper_bound                                      curr_features  \
# 0          49.884204  ['trend_user_he_mean_answ', 'lag_expl_and_part...
#
#                            new_var  count_vars  best_in_iter
# 0  content_mean_answered_correctly         107             1

# %% [markdown]
# # One factor

# %%
analyse = pd.read_csv('../analytics/block_vars_one_factor_8_2.csv')
analyse.loc[analyse.best_in_iter == 1]
# Out:
#       count  confidence_lower  confidence_upper       mean       std  \
# 0    1000.0         43.685335         44.822583  44.260591  0.297170
# 1    1000.0         43.415716         44.643160  44.029448  0.307470
# 2    1000.0         41.718775         42.943096  42.323870  0.310916
# 3    1000.0         41.629379         42.812543  42.225184  0.304373
# 4    1000.0         37.847319         39.102306  38.466800  0.320453
# 5    1000.0         37.404623         38.647076  38.051078  0.321982
# 6    1000.0         36.385913         37.660367  37.038981  0.322015
# 7    1000.0         36.305666         37.512410  36.923736  0.320254
# 8    1000.0         34.870966         36.177317  35.527307  0.335495
# 9    1000.0         34.642227         35.937706  35.286702  0.331756
# 10   1000.0         27.721238         29.049045  28.400960  0.339257
# 11   1000.0         27.270033         28.532312  27.921132  0.322624
# 12   1000.0         26.174559         27.447702  26.841641  0.327370
# ...

# %% [markdown]
# # Multi factor lgb

# %%
analyse = pd.read_csv('../analytics/block_vars_mf_multi_lgb_8_2_mark_1.csv')
analyse.loc[analyse.best_in_iter == 1]
# Out:
#       count  confidence_lower  confidence_upper       mean       std  \
# 0    1000.0         49.034925         50.166732  49.580309  0.292859
# 7    1000.0         49.000608         50.134782  49.552316  0.297510
# 25   1000.0         48.964975         50.037780  49.484407  0.283016
# 105  1000.0         48.828621         49.991449  49.404232  0.302347
# 150  1000.0         48.729534         49.923155  49.304858  0.302462
# 201  1000.0         48.599826         49.789933  49.198118  0.302109
# 247  1000.0         48.463206         49.637296  49.048538  0.305454
# 283  1000.0         48.314315         49.439438  48.860822  0.289578
# 335  1000.0         48.145484         49.293270  48.716595  0.297235
# 379  1000.0         47.962833         49.055869  48.511206  0.286457
# 443  1000.0         47.717498         48.844829  48.279679  0.292704
# 498  1000.0         47.298850         48.513758  47.907585  0.300564
# 548  1000.0         46.611607         47.750920  47.168377  0.301656
# ...

# %%
import matplotlib.pyplot as plt

plt.plot([i for i in range(14)], list(analyse.loc[analyse.best_in_iter == 1]['confidence_lower'])[::-1])

# %% [markdown]
# # Multi factor lgb (first content_he_mean_answered_correctly)

# %%
analyse = pd.read_csv('../analytics/block_vars_mf_multi_lgb_8_2_mark_3_1.csv')
analyse.loc[analyse.best_in_iter == 1]
# Out:
#       count  confidence_lower  confidence_upper       mean       std  \
# 0    1000.0         47.326406         48.565941  47.951300  0.308725
# 42   1000.0         46.711707         47.896740  47.314635  0.304382
# 92   1000.0         45.588653         46.752768  46.184304  0.301203
# 161  1000.0         37.826819         39.121155  38.459728  0.331690
#
#            min        25%        50%        75%        max  lower_boundary  \
# 0    47.000468  47.746904  47.952914  48.166389  48.992379       47.346198
# 42   46.381164  47.113260  47.323396  47.519772  48.258872       46.718046
# 92   45.364585  45.967107  46.194868  46.413915  47.043586       45.593946
# 161  37.389967  38.222816  38.457294  38.686449  39.560044       37.809615
#
#      upper_boundary       IQR  lower_whiskers  upper_whiskers  real_mean  \
# 0         48.556401  0.419484       47.117678       48.795615  47.951305
# 42        47.911224  0.406511       46.503493       48.129539  47.314785
# ...

# %%
analyse = pd.read_csv('../analytics/block_vars_mf_multi_lgb_8_2_mark_3_2.csv')
analyse.loc[analyse.best_in_iter == 1]
# Out:
#       count  confidence_lower  confidence_upper       mean       std  \
# 0    1000.0         49.120277         50.218778  49.643491  0.283367
# 8    1000.0         49.062857         50.196006  49.633884  0.293828
# 10   1000.0         49.061718         50.151931  49.634232  0.292983
# 54   1000.0         48.973584         50.129387  49.544654  0.294608
# 97   1000.0         48.882632         49.968918  49.430835  0.287080
# 150  1000.0         48.762369         49.864605  49.304442  0.284110
# 196  1000.0         48.608017         49.768272  49.164587  0.302113
# 248  1000.0         48.431783         49.563423  48.980326  0.288572
# 286  1000.0         48.287939         49.408057  48.831557  0.292749
# 347  1000.0         48.115787         49.270565  48.673167  0.292628
# 409  1000.0         47.844941         48.981222  48.425783  0.296539
#
#            min        25%        50%        75%        max  lower_boundary  \
# ...

# %%
list(analyse.loc[analyse.best_in_iter == 1, ['new_var']]['new_var'])
# Out:
# ['lag_expl_and_clu_bool',
#  'prior_question_elapsed_time',
#  'lect_user_part',
#  'user_he_sum_prior_question_elapsed_time',
#  'timestamp',
#  'lag_answ_corr',
#  'content_sum_answered_correctly',
#  'rel_user_he_mean_answ',
#  'rel_lect_part',
#  'user_sum_answered_correctly',
#  'user_ema_prior_question_elapsed_time']

# %%
analyse = pd.read_csv('../analytics/block_vars_1f_multi_lgb_8_2_mark_3_2.csv')
analyse.loc[analyse.best_in_iter == 1]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-91-f61e90b3c774> in <module>
# ----> 1 analyse = pd.read_csv('../analytics/block_vars_1f_multi_lgb_8_2_mark_3_2.csv')
#       2 analyse.loc[analyse.best_in_iter == 1]
#
# ...

# %% [markdown]
# # Multi factor

# %%
analyse = pd.read_csv('../analytics/block_vars_mf_multi_lgb_2.csv')
#analyse = analyse.loc[analyse.count_vars < 4].reset_index(drop=True)
analyse.loc[analyse.best_in_iter == 1]
# Out:
#       count  confidence_lower  confidence_upper       mean       std  \
# 0    1000.0         47.587245         48.754576  48.170071  0.301916
# 32   1000.0         46.991914         48.190647  47.572435  0.307629
# 83   1000.0         45.724164         46.915037  46.308408  0.298968
# 134  1000.0         43.710137         44.887854  44.307785  0.304648
#
#            min        25%        50%        75%        max  lower_boundary  \
# 0    47.082763  47.969755  48.162731  48.387211  49.028716       47.578316
# 32   46.518076  47.368290  47.572484  47.772639  48.605058       46.969481
# 83   45.285107  46.101969  46.297745  46.511821  47.269228       45.722431
# 134  43.395921  44.100563  44.311341  44.508077  45.322759       43.710674
#
#      upper_boundary       IQR  lower_whiskers  upper_whiskers  real_mean  \
# 0         48.761825  0.417457       47.343570       49.013397  48.170589
# 32        48.175388  0.404350       46.761765       48.379164  47.572281
# ...

# %%
analyse = pd.read_csv('../analytics/block_vars_mf_multi_lgb_auc_1.csv')
analyse.loc[analyse.best_in_iter == 1]
# Out:
#       count  confidence_lower  confidence_upper       mean       std  \
# 0    1000.0         45.503842         46.607984  46.069491  0.286866
# 2    1000.0         45.354625         46.504466  45.904748  0.296334
# 26   1000.0         44.663843         45.835606  45.220796  0.309882
# 105  1000.0         43.668777         44.906381  44.287800  0.313919
#
#            min        25%        50%        75%        max  lower_boundary  \
# 0    44.986377  45.885214  46.069255  46.253518  46.936867       45.507233
# 2    45.079268  45.693657  45.897016  46.119554  46.794861       45.323933
# 26   44.137503  45.005598  45.222061  45.430591  46.216540       44.613427
# 105  43.421445  44.072141  44.286179  44.494234  45.089859       43.672519
#
#      upper_boundary       IQR  lower_whiskers  upper_whiskers  real_mean  \
# 0         46.631749  0.368304       45.332759       46.805973  46.070204
# 2         46.485563  0.425897       45.054813       46.758399  45.904689
# ...

# %%
analyse = pd.read_csv('../analytics/block_vars_split_features_1.csv')
analyse.loc[analyse.count_vars == 4]
# Out:
#     count  confidence_lower  confidence_upper       mean       std        min  \
# 0  1000.0         47.495493         48.671011  48.076581  0.308194  47.033412
# 1  1000.0         47.470087         48.665879  48.067686  0.310321  47.104896
# 2  1000.0         47.456248         48.583533  48.031012  0.291830  46.964525
#
#          25%        50%        75%        max  lower_boundary  upper_boundary  \
# 0  47.867087  48.086425  48.281815  48.937740       47.472521       48.680642
# 1  47.867523  48.067939  48.279121  49.075176       47.459456       48.675916
# 2  47.844970  48.041022  48.227155  49.021146       47.459025       48.602999
#
#         IQR  lower_whiskers  upper_whiskers  real_mean  real_std  lower_real  \
# 0  0.414727       47.244996       48.903906  48.077146  0.306279   47.476840
# 1  0.411598       47.250126       48.896518  48.067856  0.307438   47.465277
# 2  0.382186       47.271691       48.800434  48.031295  0.288926   47.465000
#
# ...
