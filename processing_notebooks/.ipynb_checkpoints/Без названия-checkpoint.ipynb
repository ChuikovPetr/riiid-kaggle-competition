# %%
import pandas as pd

# %%
train = pd.read_csv('../data/train.csv')

# %%
train.head()
# Out:
#    row_id  timestamp  user_id  content_id  content_type_id  task_container_id  \
# 0       0          0      115        5692                0                  1
# 1       1      56943      115        5716                0                  2
# 2       2     118363      115         128                0                  0
# 3       3     131167      115        7860                0                  3
# 4       4     137965      115        7922                0                  4
#
#    user_answer  answered_correctly  prior_question_elapsed_time  \
# 0            3                   1                          NaN
# 1            2                   1                      37000.0
# 2            0                   1                      55000.0
# 3            0                   1                      19000.0
# 4            1                   1                      11000.0
#
#   prior_question_had_explanation
# 0                            NaN
# 1                          False
# ...

# %%
grouped = train.groupby(['user_id']).agg(['count'])
grouped.head()
# Out:
#         row_id timestamp content_id content_type_id task_container_id  \
#          count     count      count           count             count
# user_id
# 115         46        46         46              46                46
# 124         30        30         30              30                30
# 2746        20        20         20              20                20
# 5382       128       128        128             128               128
# 8623       112       112        112             112               112
#
#         user_answer answered_correctly prior_question_elapsed_time  \
#               count              count                       count
# user_id
# 115              46                 46                          45
# 124              30                 30                          29
# 2746             20                 20                          18
# 5382            128                128                         124
# ...

# %%
grouped.describe()
# Out:
#               row_id      timestamp     content_id content_type_id  \
#                count          count          count           count
# count  393656.000000  393656.000000  393656.000000   393656.000000
# mean      257.154297     257.154297     257.154297      257.154297
# std       747.550934     747.550934     747.550934      747.550934
# min         1.000000       1.000000       1.000000        1.000000
# 25%        30.000000      30.000000      30.000000       30.000000
# 50%        41.000000      41.000000      41.000000       41.000000
# 75%       157.000000     157.000000     157.000000      157.000000
# max     17917.000000   17917.000000   17917.000000    17917.000000
#
#       task_container_id    user_answer answered_correctly  \
#                   count          count              count
# count     393656.000000  393656.000000      393656.000000
# mean         257.154297     257.154297         257.154297
# std          747.550934     747.550934         747.550934
# ...
