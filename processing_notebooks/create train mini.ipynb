# %%
import numpy as np
import pandas as pd
pd.set_option('display.float_format', '{:.4f}'.format)

# %%
# %%time
train = pd.read_csv('../data/train.csv')
# Out:
# CPU times: user 54 s, sys: 15.1 s, total: 1min 9s
# Wall time: 2min

# %%
train.user_id.describe()
# Out:
# count    101230332.0000
# mean    1076732424.2030
# std      619716349.5006
# min            115.0000
# 25%      540811564.0000
# 50%     1071781070.0000
# 75%     1615741676.0000
# max     2147482888.0000
# Name: user_id, dtype: float64

# %%
user_ids = list(train.user_id.unique())
len(user_ids)
# Out:
# 393656

# %%
user_ids_mini = list(np.random.choice(user_ids, size = 100, replace = False))
user_ids_mini
# Out:
# [658520354,
#  406901956,
#  1953421360,
#  1485450502,
#  1929611621,
#  1588132322,
#  373598450,
#  1258176764,
#  2064777409,
#  1223491298,
#  1138522179,
#  1501524575,
#  1314342162,
#  1920216032,
#  2100847337,
#  1490239788,
#  235832844,
#  1058520883,
#  1327647142,
#  761021960,
#  2084988339,
#  736371818,
#  624222398,
#  751871997,
#  891642780,
#  1102511752,
#  82977466,
#  94999086,
#  217412465,
#  1962993593,
#  1769609168,
#  1709810594,
#  269060757,
#  1866437135,
#  1443598919,
#  957818828,
#  64764301,
#  2047398903,
#  1462950044,
#  1165196379,
#  1983836548,
#  1054103172,
#  584872865,
#  634891095,
#  2145262856,
#  1875150524,
#  1623215417,
#  951606580,
#  1944412002,
#  562186265,
#  106324700,
#  1795317519,
#  468048049,
#  1807858704,
#  337576619,
#  900124353,
#  878817883,
#  519744118,
#  1692505119,
#  1154226251,
#  2099100705,
#  1014937471,
#  348461215,
#  2143636986,
#  22318239,
#  108822628,
#  616580486,
#  1143715769,
# ...

# %%
train_mini = train[train['user_id'].isin(user_ids_mini)].reset_index(drop = True)
train_mini.head()
# Out:
#    row_id  timestamp  user_id  content_id  content_type_id  task_container_id  \
# 0  365541          0  7136928        7900                0                  0
# 1  365542      23989  7136928        7876                0                  1
# 2  365543      48079  7136928         175                0                  2
# 3  365544      74835  7136928        1278                0                  3
# 4  365545     192811  7136928        2063                0                  4
#
#    user_answer  answered_correctly  prior_question_elapsed_time  \
# 0            2                   0                          nan
# 1            0                   0                   21000.0000
# 2            3                   0                   20000.0000
# 3            1                   0                   21000.0000
# 4            3                   0                   20000.0000
#
#   prior_question_had_explanation
# 0                            NaN
# 1                          False
# ...

# %%
train_mini[train_mini['user_id'] == 7136928]
# Out:
#     row_id  timestamp  user_id  content_id  content_type_id  \
# 0   365541          0  7136928        7900                0
# 1   365542      23989  7136928        7876                0
# 2   365543      48079  7136928         175                0
# 3   365544      74835  7136928        1278                0
# 4   365545     192811  7136928        2063                0
# 5   365546     192811  7136928        2064                0
# 6   365547     192811  7136928        2065                0
# 7   365548     290933  7136928        3364                0
# 8   365549     290933  7136928        3365                0
# 9   365550     290933  7136928        3363                0
# 10  365551     370847  7136928        2947                0
# 11  365552     370847  7136928        2948                0
# 12  365553     370847  7136928        2946                0
# 13  365554     451200  7136928        2595                0
# 14  365555     451200  7136928        2593                0
# ...

# %%
train_mini.shape
# Out:
# (26892, 10)

# %%
train_mini.to_csv('../data/train_mini.csv', index = False)
